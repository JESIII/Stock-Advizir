# %%
import datetime
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import stockstats as ss
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
from joblib import dump

# %%
data = yf.download(tickers="SPY MSFT AAPL DIA QQQ F TM T AMZN", period="2y", interval="1h", group_by="ticker", prepost=True, auto_adjust=True, threads=True)
# Out:
# [*********************100%***********************]  9 of 9 completed

# %%
data = data.dropna()
data.head(20)
# Out:
#                                    TM                                      \
#                                  Open        High         Low       Close
# 2019-08-05 08:00:00-04:00  128.600000  128.600000  128.600000  128.600000
# 2019-08-05 09:30:00-04:00  129.419998  129.830002  129.009995  129.440002
# 2019-08-05 10:30:00-04:00  129.389999  129.410004  129.080002  129.089996
# 2019-08-05 11:30:00-04:00  129.089996  129.130005  128.619995  128.639999
# 2019-08-05 12:30:00-04:00  128.680099  128.680099  128.320007  128.429993
# 2019-08-05 13:30:00-04:00  128.449997  128.639999  128.110001  128.229996
# 2019-08-05 14:30:00-04:00  128.050003  128.149994  127.699997  127.940002
# 2019-08-05 15:30:00-04:00  127.919998  128.360001  127.900002  128.320007
# 2019-08-05 16:00:00-04:00  128.300000  128.300000  128.300000  128.300000
# 2019-08-06 09:30:00-04:00  127.375000  127.489998  126.300003  126.389999
# 2019-08-06 10:30:00-04:00  126.379997  126.669998  125.705002  126.046204
# ...

# %%
ticker_columns = list(dict(data.columns.values).keys())
ticker_columns
data
for ticker in ticker_columns:
    data[ticker] = data[ticker]["Open", "Close", "High", "Low", "Volume"]
    data[ticker]["amount"] = 0
data.head(10)
# spy_data, tm_data, amzn_data, msft_data, qqq_data, dia_data, f_data, aapl_data = data.SPY, data.TM, data.AMZN, data.MSFT, data.DIA, data.F, data.AAPL
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Open', 'Close', 'High', 'Low', 'Volume')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-b4f2201151bf> in <module>
# ...
